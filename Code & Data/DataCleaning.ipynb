# %%
import os
import numpy as np
import pandas as pd
import math
from matplotlib import pyplot as plt

# %%
def isfloat(num):
    try:
        float(num)
        return True
    except ValueError:
        return False

# %%
def deletCols(df, keep):
    remove = []
    for i in range(len(df.columns)):
        column = df.columns[i]
        if(column not in keep):
            remove.append(column)

    return df.drop(remove, axis=1)

def renameCols(df, suffix):
    for column in df.columns:
        df = df.rename(columns={column: f'{column}_{suffix}'})
    
    return df

def setCol(df, idx):
    df.columns = df.iloc[idx]
    df = df.drop(df.index[idx])

    return df

def dfStringToNum(df):
    for i in range(df.shape[0]): #iterate over rows
        for j in range(df.shape[1]): #iterate over columns
            value = df.iat[i, j] #get cell value
            if (not (value.isnumeric() or isfloat(value))):
                df.iat[i, j] = 0
    return df

def dropNAN(df):
    for i in range(df.shape[0]): #iterate over rows
        for j in range(df.shape[1]): #iterate over columns
            value = df.iat[i, j] #get cell value
            if (not (value.isnumeric() or isfloat(value))):
                df.iat[i, j] = np.nan
    return df

# %% [markdown]
# <h3>GHG For Every Country</h3>

# %%
countries = []
#Transposing Data
ghg = pd.read_csv("Macro/GHG Energy.csv")
#reset column header to year
ghg.columns = ghg.iloc[2]
ghg = ghg.reset_index(drop=True)
ghg.columns.name = None
#move years (the current column header) to the index
ghg = ghg.transpose()
#set country names as column headers
ghg = setCol(ghg, 0)
#remove name
ghg.columns.name = None
#remove all columns with header name null
ghg = ghg.loc[:, ghg.columns.notnull()]

#Remove columns
col_keep = ["World"]
start = 0
end = 0

for i in range(len(ghg.columns)):
    column = ghg.columns[i]
    if column == "Canada":
        start = i
    if column == "Middle East":
        end = i

for i in range(start, end):
    col_keep.append(ghg.columns[i])

countries = col_keep
countries.pop(countries.index("Kosovo"))

ghg = deletCols(ghg, col_keep)

ghg = renameCols(ghg, "ghg")
ghg = dfStringToNum(ghg)

ghg.head()
# Out:
#      World_ghg Canada_ghg Chile_ghg Mexico_ghg United States_ghg  \
# 1971     16121        366        22        118              4581
# 1972     16840        385        22        131              4825
# 1973     17771        404        21        143              4987
# 1974     17722        413        21        156              4823
# 1975     17768        404        18        163              4631
#
#      OECD Americas_ghg Australia_ghg Israel_ghg Japan_ghg Korea_ghg  ...  \
# 1971              5118           151         14       762        56  ...
# 1972              5395           157         15       799        58  ...
# 1973              5589           166         16       909        72  ...
# 1974              5448           181         16       896        75  ...
# 1975              5249           189         17       860        82  ...
#
#      Jordan_ghg Kuwait_ghg Lebanon_ghg Oman_ghg Qatar_ghg Saudi Arabia_ghg  \
# 1971          1         65           5       13        13               88
# 1972          2         66           5       13        14              104
# 1973          2         59           7       13        15              124
# 1974          2         48           7       13        15              139
# 1975          2         40           6       13        17              142
#
#      Syrian Arab Republic _ghg United Arab Emirates_ghg Yemen_ghg Africa_ghg
# 1971                        13                       36         1        525
# 1972                        14                       40         1        533
# 1973                        14                       46         2        561
# 1974                        17                       51         2        558
# 1975                        22                       56         2        579
#
# [5 rows x 160 columns]

# %% [markdown]
# <h3>Investment: R&D per thousands of GDP</h3>

# %%
rd = pd.read_csv("Macro/R&D.csv")
rd = setCol(rd, 0)

for index, row in rd.iterrows():
    if(row["Indicator"].strip() != "RD&D per thousand units of GDP"):
        rd = rd.drop(index)

rd = rd.drop(columns="Indicator")
rd.columns.name = None
rd = rd.transpose()
rd = setCol(rd, 0)
for column in rd.columns:
    if(column not in countries):
        rd = rd.drop(column, axis=1)
rd.columns.name = None
rd = rd.drop(rd.index[-1])
rd = renameCols(rd, "r&d")
rd = dfStringToNum(rd)

rd.head()
# Out:
#      Australia_r&d Austria_r&d Belgium_r&d Brazil_r&d Canada_r&d  \
# 1974             0           0       1.262          0      0.854
# 1975             0           0       1.456          0      0.782
# 1976             0           0       1.329          0      0.778
# 1977             0       0.321       1.098          0      0.824
# 1978             0       0.398        0.84          0      1.023
#
#      Czech Republic_r&d Denmark_r&d Estonia_r&d Finland_r&d France_r&d  ...  \
# 1974                  0           0           0           0          0  ...
# 1975                  0       0.215           0           0          0  ...
# 1976                  0       0.223           0           0          0  ...
# 1977                  0       0.328           0           0          0  ...
# 1978                  0        0.41           0           0          0  ...
#
#      Norway_r&d Poland_r&d Portugal_r&d Slovak Republic_r&d Spain_r&d  \
# 1974      0.154          0            0                   0     0.311
# 1975      0.092          0            0                   0     0.304
# 1976      0.093          0            0                   0     0.305
# 1977      0.103          0            0                   0     0.238
# 1978      0.649          0            0                   0     0.292
#
#      Sweden_r&d Switzerland_r&d Turkey_r&d United Kingdom_r&d  \
# 1974      0.227           0.043          0              1.033
# 1975       0.57           0.054          0              1.015
# 1976      0.498           0.068          0              1.022
# 1977      0.649           0.177          0              0.821
# 1978      0.784           0.368          0              0.961
#
#      United States_r&d
# 1974             0.523
# 1975             0.727
# 1976             0.811
# 1977             1.183
# 1978             1.302
#
# [5 rows x 32 columns]

# %%
df = rd.join(ghg)
df.head()
# Out:
#      Australia_r&d Austria_r&d Belgium_r&d Brazil_r&d Canada_r&d  \
# 1974             0           0       1.262          0      0.854
# 1975             0           0       1.456          0      0.782
# 1976             0           0       1.329          0      0.778
# 1977             0       0.321       1.098          0      0.824
# 1978             0       0.398        0.84          0      1.023
#
#      Czech Republic_r&d Denmark_r&d Estonia_r&d Finland_r&d France_r&d  ...  \
# 1974                  0           0           0           0          0  ...
# 1975                  0       0.215           0           0          0  ...
# 1976                  0       0.223           0           0          0  ...
# 1977                  0       0.328           0           0          0  ...
# 1978                  0        0.41           0           0          0  ...
#
#      Jordan_ghg Kuwait_ghg Lebanon_ghg Oman_ghg Qatar_ghg Saudi Arabia_ghg  \
# 1974          2         48           7       13        15              139
# 1975          2         40           6       13        17              142
# 1976          3         41           5       15        16              176
# 1977          3         40           5       15        14              189
# 1978          3         45           6        4        16              190
#
#      Syrian Arab Republic _ghg United Arab Emirates_ghg Yemen_ghg Africa_ghg
# 1974                        17                       51         2        558
# 1975                        22                       56         2        579
# 1976                        24                       66         2        650
# 1977                        25                       67         2        674
# 1978                        23                       57         2        667
#
# [5 rows x 193 columns]

# %%
for i in df.columns:
    df[i] = df[i].astype(float)

df.index = df.index.astype(int)

# %%
def getRdGhgList(country):
    rd_list = df[f"{country}_r&d"].tolist()
    ghg_list = df[f"{country}_ghg"].tolist()
    year_list = df.index.tolist()
    
    return [rd_list, ghg_list, year_list]

def getRdGhgDf(country):
    df[f"{country}_r&d"] = df[f"{country}_r&d"].astype(float)
    df[f"{country}_ghg"] = df[f"{country}_ghg"].astype(float)
    return df[[f"{country}_r&d", f"{country}_ghg"]]

# %%
test = getRdGhgDf("Canada")
test.plot(kind="scatter", x="Canada_r&d", y="Canada_ghg")
# Out:
# <AxesSubplot:xlabel='Canada_r&d', ylabel='Canada_ghg'>

# %% [markdown]
# <h3>Our World in Data</h3>

# %%
owid = pd.read_csv("Macro/owid-energy-data.csv")
owid
# Out:
#       iso_code      country  year  coal_prod_change_pct  coal_prod_change_twh  \
# 0          AFG  Afghanistan  1900                   NaN                   NaN
# 1          AFG  Afghanistan  1901                   NaN                 0.000
# 2          AFG  Afghanistan  1902                   NaN                 0.000
# 3          AFG  Afghanistan  1903                   NaN                 0.000
# 4          AFG  Afghanistan  1904                   NaN                 0.000
# ...        ...          ...   ...                   ...                   ...
# 17427      ZWE     Zimbabwe  2015               -25.013               -10.847
# 17428      ZWE     Zimbabwe  2016               -37.694               -12.257
# 17429      ZWE     Zimbabwe  2017                 8.375                 1.697
# 17430      ZWE     Zimbabwe  2018                22.555                 4.952
# 17431      ZWE     Zimbabwe  2019               -35.015                -9.422
#
#        gas_prod_change_pct  gas_prod_change_twh  oil_prod_change_pct  \
# 0                      NaN                  NaN                  NaN
# 1                      NaN                  NaN                  NaN
# 2                      NaN                  NaN                  NaN
# 3                      NaN                  NaN                  NaN
# 4                      NaN                  NaN                  NaN
# ...                    ...                  ...                  ...
# 17427                  NaN                  NaN                  NaN
# 17428                  NaN                  NaN                  NaN
# 17429                  NaN                  NaN                  NaN
# 17430                  NaN                  NaN                  NaN
# 17431                  NaN                  NaN                  NaN
#
#        oil_prod_change_twh  energy_cons_change_pct  ...  \
# 0                      NaN                     NaN  ...
# 1                      NaN                     NaN  ...
# 2                      NaN                     NaN  ...
# 3                      NaN                     NaN  ...
# 4                      NaN                     NaN  ...
# ...                    ...                     ...  ...
# 17427                  NaN                  -0.789  ...
# 17428                  NaN                 -14.633  ...
# 17429                  NaN                     NaN  ...
# 17430                  NaN                     NaN  ...
# 17431                  NaN                     NaN  ...
#
#        solar_elec_per_capita  solar_energy_per_capita           gdp  \
# 0                        NaN                      NaN           NaN
# 1                        NaN                      NaN           NaN
# 2                        NaN                      NaN           NaN
# 3                        NaN                      NaN           NaN
# 4                        NaN                      NaN           NaN
# ...                      ...                      ...           ...
# 17427                  0.579                      NaN  2.503057e+10
# 17428                  0.641                      NaN  2.515176e+10
# 17429                  0.773                      NaN           NaN
# 17430                  0.970                      NaN           NaN
# 17431                  0.956                      NaN           NaN
#
#        wind_share_elec  wind_cons_change_pct  wind_share_energy  \
# 0                  NaN                   NaN                NaN
# 1                  NaN                   NaN                NaN
# 2                  NaN                   NaN                NaN
# 3                  NaN                   NaN                NaN
# 4                  NaN                   NaN                NaN
# ...                ...                   ...                ...
# 17427              0.0                   NaN                NaN
# 17428              0.0                   NaN                NaN
# 17429              0.0                   NaN                NaN
# 17430              0.0                   NaN                NaN
# 17431              0.0                   NaN                NaN
#
#        wind_cons_change_twh  wind_consumption  wind_elec_per_capita  \
# 0                       NaN               NaN                   NaN
# 1                       NaN               NaN                   NaN
# 2                       NaN               NaN                   NaN
# 3                       NaN               NaN                   NaN
# 4                       NaN               NaN                   NaN
# ...                     ...               ...                   ...
# 17427                   NaN               NaN                   0.0
# 17428                   NaN               NaN                   0.0
# 17429                   NaN               NaN                   0.0
# 17430                   NaN               NaN                   0.0
# 17431                   NaN               NaN                   0.0
#
#        wind_energy_per_capita
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 17427                     NaN
# 17428                     NaN
# 17429                     NaN
# 17430                     NaN
# 17431                     NaN
#
# [17432 rows x 122 columns]

# %%
def binarySearch(arr, start, end, val):
    if(start <= end):
        mid = math.floor((start + end) / 2)
        if arr[mid] > val:
            #we can - 1 since we have just checked the mid index
            return binarySearch(arr, start, mid - 1, val)
        elif arr[mid] < val:
            return binarySearch(arr, mid + 1, end, val)
        else:
            return mid

# %%
def getOwidCountry(df, country):
    row_num = binarySearch(df["country"], 0, len(df["country"]) - 1, country)
    year_of_row = df.iloc[row_num]["year"]
    start_slice = year_of_row - 1900
    end_slice = 2020 - year_of_row
    df = df.iloc[row_num - start_slice : end_slice + row_num + 1]
    extra = []
    for i in range(df.shape[0]):
        if str(df.iloc[[i]]["country"].values[0]) != country:
            extra.append(df.iloc[[i]].index.values[0])

    return df.drop(extra)

# %%
c = getOwidCountry("Canada")
c = c.set_index(c["year"])
c.columns.name = None

def getProductionConsumption(energy_type, production, df):
    start = df.index.values[0]
    country = df["country"][start]
    if production:
        df[f"{energy_type}_electricity_{country}"] = df[f"{energy_type}_electricity"]
        return df[f"{energy_type}_electricity_{country}"]
    else:
        arr = []
        for i in range(df.shape[0]):
            total_elec = df["per_capita_electricity"][start+i] * df["population"][start+i]
            arr.append(total_elec * df[f"{energy_type}_share_elec"][start+i])
        df[f"elec_consumption_{energy_type}_{country}"] = arr
        return df[f"elec_consumption_{energy_type}_{country}"]

test = getProductionConsumption("fossil", False, c)
test.dropna().plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
owid_ghg = pd.read_csv("Macro/owid-co2-data.csv")
# owid_ghg = owid_ghg.set_index(owid_ghg['year'])
# owid_ghg = owid_ghg[["country", "co2", "year"]]
owid_ghg
# Out:
#       iso_code      country  year     co2  consumption_co2  co2_growth_prct  \
# 0          AFG  Afghanistan  1949   0.015              NaN              NaN
# 1          AFG  Afghanistan  1950   0.084              NaN           475.00
# 2          AFG  Afghanistan  1951   0.092              NaN             8.70
# 3          AFG  Afghanistan  1952   0.092              NaN             0.00
# 4          AFG  Afghanistan  1953   0.106              NaN            16.00
# ...        ...          ...   ...     ...              ...              ...
# 25199      ZWE     Zimbabwe  2016  10.738           12.153           -12.17
# 25200      ZWE     Zimbabwe  2017   9.582           11.248           -10.77
# 25201      ZWE     Zimbabwe  2018  11.854           13.163            23.72
# 25202      ZWE     Zimbabwe  2019  10.949           12.422            -7.64
# 25203      ZWE     Zimbabwe  2020  10.531              NaN            -3.82
#
#        co2_growth_abs  trade_co2  co2_per_capita  consumption_co2_per_capita  \
# 0                 NaN        NaN           0.002                         NaN
# 1               0.070        NaN           0.011                         NaN
# 2               0.007        NaN           0.012                         NaN
# 3               0.000        NaN           0.012                         NaN
# 4               0.015        NaN           0.013                         NaN
# ...               ...        ...             ...                         ...
# 25199          -1.488      1.415           0.765                       0.866
# 25200          -1.156      1.666           0.673                       0.790
# 25201           2.273      1.308           0.821                       0.912
# 25202          -0.905      1.473           0.748                       0.848
# 25203          -0.418        NaN           0.709                         NaN
#
#        ...  ghg_per_capita  methane  methane_per_capita  nitrous_oxide  \
# 0      ...             NaN      NaN                 NaN            NaN
# 1      ...             NaN      NaN                 NaN            NaN
# 2      ...             NaN      NaN                 NaN            NaN
# 3      ...             NaN      NaN                 NaN            NaN
# 4      ...             NaN      NaN                 NaN            NaN
# ...    ...             ...      ...                 ...            ...
# 25199  ...           4.703    11.92                0.85           6.55
# 25200  ...             NaN      NaN                 NaN            NaN
# 25201  ...             NaN      NaN                 NaN            NaN
# 25202  ...             NaN      NaN                 NaN            NaN
# 25203  ...             NaN      NaN                 NaN            NaN
#
#        nitrous_oxide_per_capita  population           gdp  \
# 0                           NaN   7624058.0           NaN
# 1                           NaN   7752117.0  9.421400e+09
# 2                           NaN   7840151.0  9.692280e+09
# 3                           NaN   7935996.0  1.001732e+10
# 4                           NaN   8039684.0  1.063052e+10
# ...                         ...         ...           ...
# 25199                     0.467  14030338.0  2.096179e+10
# 25200                       NaN  14236599.0  2.194784e+10
# 25201                       NaN  14438812.0  2.271535e+10
# 25202                       NaN  14645473.0           NaN
# 25203                       NaN  14862927.0           NaN
#
#        primary_energy_consumption  energy_per_capita  energy_per_gdp
# 0                             NaN                NaN             NaN
# 1                             NaN                NaN             NaN
# 2                             NaN                NaN             NaN
# 3                             NaN                NaN             NaN
# 4                             NaN                NaN             NaN
# ...                           ...                ...             ...
# 25199                        47.5           3385.574           1.889
# 25200                         NaN                NaN             NaN
# 25201                         NaN                NaN             NaN
# 25202                         NaN                NaN             NaN
# 25203                         NaN                NaN             NaN
#
# [25204 rows x 58 columns]

# %% [markdown]
# <h3>Full Data</h3>

# %%
for i in owid['country'].unique():
    if i not in owid_ghg['country'].unique():
        countries.append(i)

# %%
append_owid = owid
for index, row in append_owid.iterrows():
    if row["country"] not in countries:
        append_owid = append_owid.drop(owid.index[index])
    elif row["year"] < 2000 or row["year"] > 2019 or (row['year'] == 2020 and owid.iloc[index-1] < 1999):
        append_owid = append_owid.drop(owid.index[index])

append_owid = append_owid.reset_index()

# %%
append_owid
# Out:
#       index iso_code   country  year  coal_prod_change_pct  \
# 0       220      NaN    Africa  2000                -0.087
# 1       221      NaN    Africa  2001                -0.248
# 2       222      NaN    Africa  2002                -1.673
# 3       223      NaN    Africa  2003                 7.458
# 4       224      NaN    Africa  2004                 2.181
# ...     ...      ...       ...   ...                   ...
# 3117  17427      ZWE  Zimbabwe  2015               -25.013
# 3118  17428      ZWE  Zimbabwe  2016               -37.694
# 3119  17429      ZWE  Zimbabwe  2017                 8.375
# 3120  17430      ZWE  Zimbabwe  2018                22.555
# 3121  17431      ZWE  Zimbabwe  2019               -35.015
#
#       coal_prod_change_twh  gas_prod_change_pct  gas_prod_change_twh  \
# 0                   -1.320               11.037              134.287
# 1                   -3.761                3.363               45.431
# 2                  -25.333                4.557               63.640
# 3                  111.037                7.425              108.417
# 4                   34.898                4.627               72.579
# ...                    ...                  ...                  ...
# 3117               -10.847                  NaN                  NaN
# 3118               -12.257                  NaN                  NaN
# 3119                 1.697                  NaN                  NaN
# 3120                 4.952                  NaN                  NaN
# 3121                -9.422                  NaN                  NaN
#
#       oil_prod_change_pct  oil_prod_change_twh  ...  solar_elec_per_capita  \
# 0                   7.284              292.915  ...                  0.016
# 1                  -1.002              -43.243  ...                  0.020
# 2                   0.679               28.986  ...                  0.023
# 3                   8.758              376.609  ...                  0.026
# 4                  11.272              527.174  ...                  0.031
# ...                   ...                  ...  ...                    ...
# 3117                  NaN                  NaN  ...                  0.579
# 3118                  NaN                  NaN  ...                  0.641
# 3119                  NaN                  NaN  ...                  0.773
# 3120                  NaN                  NaN  ...                  0.970
# 3121                  NaN                  NaN  ...                  0.956
#
#       solar_energy_per_capita           gdp  wind_share_elec  \
# 0                       0.045           NaN            0.040
# 1                       0.054           NaN            0.091
# 2                       0.063           NaN            0.092
# 3                       0.072           NaN            0.107
# 4                       0.083           NaN            0.144
# ...                       ...           ...              ...
# 3117                      NaN  2.503057e+10            0.000
# 3118                      NaN  2.515176e+10            0.000
# 3119                      NaN           NaN            0.000
# 3120                      NaN           NaN            0.000
# 3121                      NaN           NaN            0.000
#
#       wind_cons_change_pct  wind_share_energy  wind_cons_change_twh  \
# 0                  788.889              0.015                 0.434
# 1                  134.874              0.035                 0.659
# 2                    6.161              0.036                 0.071
# 3                   20.951              0.042                 0.255
# 4                   41.238              0.055                 0.608
# ...                    ...                ...                   ...
# 3117                   NaN                NaN                   NaN
# 3118                   NaN                NaN                   NaN
# 3119                   NaN                NaN                   NaN
# 3120                   NaN                NaN                   NaN
# 3121                   NaN                NaN                   NaN
#
#       wind_consumption  wind_elec_per_capita  wind_energy_per_capita
# 0                0.489                 0.217                   0.603
# 1                1.148                 0.501                   1.382
# 2                1.219                 0.522                   1.432
# 3                1.474                 0.620                   1.690
# 4                2.082                 0.861                   2.330
# ...                ...                   ...                     ...
# 3117               NaN                 0.000                     NaN
# 3118               NaN                 0.000                     NaN
# 3119               NaN                 0.000                     NaN
# 3120               NaN                 0.000                     NaN
# 3121               NaN                 0.000                     NaN
#
# [3122 rows x 123 columns]

# %%
append_rd = rd[2000-1974:]
append_rd.head()
# Out:
#      Australia_r&d Austria_r&d Belgium_r&d Brazil_r&d Canada_r&d  \
# 2000             0       0.109           0          0      0.241
# 2001         0.206       0.136           0          0      0.256
# 2002             0       0.129           0          0      0.269
# 2003         0.176       0.108           0          0       0.29
# 2004          0.34       0.138           0          0      0.235
#
#      Czech Republic_r&d Denmark_r&d Estonia_r&d Finland_r&d France_r&d  ...  \
# 2000                  0       0.247           0        0.48      0.397  ...
# 2001                  0       0.239           0       0.434      0.287  ...
# 2002                  0       0.119           0       0.475       0.62  ...
# 2003              0.063       0.123           0       0.389      0.614  ...
# 2004              0.042        0.23           0       0.504       0.58  ...
#
#      Norway_r&d Poland_r&d Portugal_r&d Slovak Republic_r&d Spain_r&d  \
# 2000      0.246          0        0.011                   0     0.076
# 2001      0.246          0        0.007                   0     0.071
# 2002      0.252          0        0.014                   0     0.061
# 2003      0.237          0        0.018                   0     0.069
# 2004      0.266          0         0.02                   0     0.051
#
#      Sweden_r&d Switzerland_r&d Turkey_r&d United Kingdom_r&d  \
# 2000      0.269           0.353      0.013              0.044
# 2001      0.305           0.356      0.015              0.027
# 2002      0.328           0.371      0.011               0.03
# 2003      0.322           0.376      0.011              0.027
# 2004      0.327            0.32      0.002              0.037
#
#      United States_r&d
# 2000             0.221
# 2001             0.266
# 2002              0.26
# 2003              0.24
# 2004             0.237
#
# [5 rows x 32 columns]

# %%
list_to_append = []
for i in range(0, append_owid.shape[0], 20):
    if append_owid.iloc[i]["year"] != 2000:
        print(append_owid.iloc[i])
    country = append_owid.iloc[i]["country"]
    if country+"_r&d" in append_rd.columns.values:
        for value in append_rd[country+"_r&d"].to_list():
            list_to_append.append(float(value))
    else:
        for i in range(20):
            list_to_append.append(np.NaN)

append_owid['rd'] = list_to_append
# Out:
# index                        4548
# iso_code                      DNK
# country                   Denmark
# year                         2003
# coal_prod_change_pct            0
#                            ...
# wind_share_energy           5.986
# wind_cons_change_twh        1.777
# wind_consumption            15.15
# wind_elec_per_capita       1032.3
# wind_energy_per_capita    2812.25
# Name: 700, Length: 123, dtype: object
# index                                   4669
# iso_code                                 DOM
# country                   Dominican Republic
# year                                    2003
# coal_prod_change_pct                     NaN
#                                  ...
# wind_share_energy                        NaN
# wind_cons_change_twh                     NaN
# wind_consumption                         NaN
# wind_elec_per_capita                       0
# wind_energy_per_capita                   NaN
# Name: 720, Length: 123, dtype: object
# index                               4724
# iso_code                             NaN
# country                   Eastern Africa
# year                                2003
# coal_prod_change_pct                 NaN
#                                ...
# wind_share_energy                    NaN
# wind_cons_change_twh                 NaN
# wind_consumption                     NaN
# wind_elec_per_capita                 NaN
# wind_energy_per_capita               NaN
# Name: 740, Length: 123, dtype: object
# index                        4844
# iso_code                      ECU
# country                   Ecuador
# year                         2003
# coal_prod_change_pct          NaN
#                            ...
# wind_share_energy               0
# wind_cons_change_twh            0
# wind_consumption                0
# wind_elec_per_capita            0
# wind_energy_per_capita          0
# Name: 760, Length: 123, dtype: object
# index                       4964
# iso_code                     EGY
# country                    Egypt
# year                        2003
# coal_prod_change_pct         NaN
#                            ...
# wind_share_energy          0.122
# wind_cons_change_twh       0.197
# wind_consumption           0.779
# wind_elec_per_capita       5.053
# wind_energy_per_capita    10.699
# Name: 780, Length: 123, dtype: object
# index                            5004
# iso_code                          SLV
# country                   El Salvador
# year                             2003
# coal_prod_change_pct              NaN
#                              ...
# wind_share_energy                 NaN
# wind_cons_change_twh              NaN
# wind_consumption                  NaN
# wind_elec_per_capita                0
# wind_energy_per_capita            NaN
# Name: 800, Length: 123, dtype: object
# index                                  5044
# iso_code                                GNQ
# country                   Equatorial Guinea
# year                                   2003
# coal_prod_change_pct                    NaN
#                                 ...
# wind_share_energy                       NaN
# wind_cons_change_twh                    NaN
# wind_consumption                        NaN
# wind_elec_per_capita                      0
# wind_energy_per_capita                  NaN
# Name: 820, Length: 123, dtype: object
# index                        5070
# iso_code                      ERI
# country                   Eritrea
# year                         2003
# coal_prod_change_pct          NaN
#                            ...
# wind_share_energy             NaN
# wind_cons_change_twh          NaN
# wind_consumption              NaN
# wind_elec_per_capita            0
# wind_energy_per_capita        NaN
# Name: 840, Length: 123, dtype: object
# index                        5105
# iso_code                      EST
# country                   Estonia
# year                         2003
# coal_prod_change_pct          NaN
#                            ...
# wind_share_energy           0.027
# wind_cons_change_twh        0.013
# wind_consumption            0.017
# wind_elec_per_capita         4.37
# wind_energy_per_capita     12.104
# Name: 860, Length: 123, dtype: object
# index                         5263
# iso_code                       ETH
# country                   Ethiopia
# year                          2003
# coal_prod_change_pct           NaN
#                             ...
# wind_share_energy              NaN
# wind_cons_change_twh           NaN
# wind_consumption               NaN
# wind_elec_per_capita             0
# wind_energy_per_capita         NaN
# Name: 880, Length: 123, dtype: object
# index                               5438
# iso_code                             NaN
# country                   Europe (other)
# year                                2003
# coal_prod_change_pct               7.743
#                                ...
# wind_share_energy                    NaN
# wind_cons_change_twh                 NaN
# wind_consumption                     NaN
# wind_elec_per_capita                 NaN
# wind_energy_per_capita               NaN
# Name: 900, Length: 123, dtype: object
# index                                 5515
# iso_code                               NaN
# country                   Falkland Islands
# year                                  2003
# coal_prod_change_pct                   NaN
#                                 ...
# wind_share_energy                      NaN
# wind_cons_change_twh                   NaN
# wind_consumption                       NaN
# wind_elec_per_capita                   NaN
# wind_energy_per_capita                 NaN
# Name: 920, Length: 123, dtype: object
# index                        5610
# iso_code                      FIN
# country                   Finland
# year                         2006
# coal_prod_change_pct          NaN
#                            ...
# wind_share_energy           0.107
# wind_cons_change_twh       -0.045
# wind_consumption            0.408
# wind_elec_per_capita       29.494
# wind_energy_per_capita     77.347
# Name: 940, Length: 123, dtype: object
# index                       5731
# iso_code                     FRA
# country                   France
# year                        2006
# coal_prod_change_pct           0
#                            ...
# wind_share_energy          0.189
# wind_cons_change_twh       3.245
# wind_consumption           5.832
# wind_elec_per_capita      35.484
# wind_energy_per_capita    94.822
# Name: 960, Length: 123, dtype: object
# index                      5932
# iso_code                    GAB
# country                   Gabon
# year                       2006
# coal_prod_change_pct        NaN
#                           ...
# wind_share_energy           NaN
# wind_cons_change_twh        NaN
# wind_consumption            NaN
# wind_elec_per_capita          0
# wind_energy_per_capita      NaN
# Name: 980, Length: 123, dtype: object
# index                        6000
# iso_code                      GEO
# country                   Georgia
# year                         2006
# coal_prod_change_pct           80
#                            ...
# wind_share_energy             NaN
# wind_cons_change_twh          NaN
# wind_consumption              NaN
# wind_elec_per_capita            0
# wind_energy_per_capita        NaN
# Name: 1000, Length: 123, dtype: object
# index                        6120
# iso_code                      DEU
# country                   Germany
# year                         2006
# coal_prod_change_pct       -5.696
#                            ...
# wind_share_energy           2.036
# wind_cons_change_twh        8.844
# wind_consumption           82.087
# wind_elec_per_capita      385.408
# wind_energy_per_capita    1007.54
# Name: 1020, Length: 123, dtype: object
# index                      6241
# iso_code                    GHA
# country                   Ghana
# year                       2006
# coal_prod_change_pct        NaN
#                           ...
# wind_share_energy           NaN
# wind_cons_change_twh        NaN
# wind_consumption            NaN
# wind_elec_per_capita          0
# wind_energy_per_capita      NaN
# Name: 1040, Length: 123, dtype: object
# index                          6281
# iso_code                        GIB
# country                   Gibraltar
# year                           2006
# coal_prod_change_pct            NaN
#                             ...
# wind_share_energy               NaN
# wind_cons_change_twh            NaN
# wind_consumption                NaN
# wind_elec_per_capita              0
# wind_energy_per_capita          NaN
# Name: 1060, Length: 123, dtype: object
# index                        6401
# iso_code                      GRC
# country                    Greece
# year                         2006
# coal_prod_change_pct       -4.307
#                            ...
# wind_share_energy           1.087
# wind_cons_change_twh        1.136
# wind_consumption            4.541
# wind_elec_per_capita      151.931
# wind_energy_per_capita    406.022
# Name: 1080, Length: 123, dtype: object
# index                     6642
# iso_code                   GUM
# country                   Guam
# year                      2006
# coal_prod_change_pct       NaN
#                           ...
# wind_share_energy          NaN
# wind_cons_change_twh       NaN
# wind_consumption           NaN
# wind_elec_per_capita         0
# wind_energy_per_capita     NaN
# Name: 1100, Length: 123, dtype: object
# index                          6762
# iso_code                        GTM
# country                   Guatemala
# year                           2006
# coal_prod_change_pct            NaN
#                             ...
# wind_share_energy               NaN
# wind_cons_change_twh            NaN
# wind_consumption                NaN
# wind_elec_per_capita              0
# wind_energy_per_capita          NaN
# Name: 1120, Length: 123, dtype: object
# index                       6882
# iso_code                     GUY
# country                   Guyana
# year                        2006
# coal_prod_change_pct         NaN
#                            ...
# wind_share_energy            NaN
# wind_cons_change_twh         NaN
# wind_consumption             NaN
# wind_elec_per_capita           0
# wind_energy_per_capita       NaN
# Name: 1140, Length: 123, dtype: object
# index                      6922
# iso_code                    HTI
# country                   Haiti
# year                       2006
# coal_prod_change_pct        NaN
#                           ...
# wind_share_energy           NaN
# wind_cons_change_twh        NaN
# wind_consumption            NaN
# wind_elec_per_capita          0
# wind_energy_per_capita      NaN
# Name: 1160, Length: 123, dtype: object
# index                         6962
# iso_code                       HND
# country                   Honduras
# year                          2006
# coal_prod_change_pct           NaN
#                             ...
# wind_share_energy              NaN
# wind_cons_change_twh           NaN
# wind_consumption               NaN
# wind_elec_per_capita             0
# wind_energy_per_capita         NaN
# Name: 1180, Length: 123, dtype: object
# index                        7137
# iso_code                      HUN
# country                   Hungary
# year                         2006
# coal_prod_change_pct        0.484
#                            ...
# wind_share_energy           0.038
# wind_cons_change_twh        0.088
# wind_consumption            0.115
# wind_elec_per_capita        4.312
# wind_energy_per_capita      11.43
# Name: 1200, Length: 123, dtype: object
# index                        7193
# iso_code                      ISL
# country                   Iceland
# year                         2006
# coal_prod_change_pct          NaN
#                            ...
# wind_share_energy               0
# wind_cons_change_twh            0
# wind_consumption                0
# wind_elec_per_capita            0
# wind_energy_per_capita          0
# Name: 1220, Length: 123, dtype: object
# index                       7313
# iso_code                     IND
# country                    India
# year                        2006
# coal_prod_change_pct       4.373
#                            ...
# wind_share_energy          0.516
# wind_cons_change_twh       8.843
# wind_consumption          24.958
# wind_elec_per_capita       7.456
# wind_energy_per_capita    21.414
# Name: 1240, Length: 123, dtype: object
# index                          7434
# iso_code                        IDN
# country                   Indonesia
# year                           2006
# coal_prod_change_pct         26.872
#                             ...
# wind_share_energy                 0
# wind_cons_change_twh              0
# wind_consumption                  0
# wind_elec_per_capita              0
# wind_energy_per_capita            0
# Name: 1260, Length: 123, dtype: object
# index                     7675
# iso_code                   IRQ
# country                   Iraq
# year                      2006
# coal_prod_change_pct       NaN
#                           ...
# wind_share_energy            0
# wind_cons_change_twh         0
# wind_consumption             0
# wind_elec_per_capita         0
# wind_energy_per_capita       0
# Name: 1280, Length: 123, dtype: object
# index                        7795
# iso_code                      IRL
# country                   Ireland
# year                         2006
# coal_prod_change_pct            0
#                            ...
# wind_share_energy            2.27
# wind_cons_change_twh        1.345
# wind_consumption            4.336
# wind_elec_per_capita      383.371
# wind_energy_per_capita    1024.92
# Name: 1300, Length: 123, dtype: object
# index                       7916
# iso_code                     ISR
# country                   Israel
# year                        2006
# coal_prod_change_pct         NaN
#                            ...
# wind_share_energy          0.011
# wind_cons_change_twh      -0.003
# wind_consumption           0.027
# wind_elec_per_capita       1.497
# wind_energy_per_capita     4.001
# Name: 1320, Length: 123, dtype: object
# index                       8036
# iso_code                     ITA
# country                    Italy
# year                        2006
# coal_prod_change_pct           0
#                            ...
# wind_share_energy          0.365
# wind_cons_change_twh       1.639
# wind_consumption           7.941
# wind_elec_per_capita      50.744
# wind_energy_per_capita    135.65
# Name: 1340, Length: 123, dtype: object
# index                        8077
# iso_code                      JAM
# country                   Jamaica
# year                         2006
# coal_prod_change_pct          NaN
#                            ...
# wind_share_energy             NaN
# wind_cons_change_twh          NaN
# wind_consumption              NaN
# wind_elec_per_capita       19.971
# wind_energy_per_capita        NaN
# Name: 1360, Length: 123, dtype: object
# index                       8197
# iso_code                     JPN
# country                    Japan
# year                        2006
# coal_prod_change_pct      22.118
#                            ...
# wind_share_energy          0.092
# wind_cons_change_twh       0.569
# wind_consumption           5.707
# wind_elec_per_capita      17.209
# wind_energy_per_capita    44.437
# Name: 1380, Length: 123, dtype: object
# index                       8238
# iso_code                     JOR
# country                   Jordan
# year                        2006
# coal_prod_change_pct         NaN
#                            ...
# wind_share_energy            NaN
# wind_cons_change_twh         NaN
# wind_consumption             NaN
# wind_elec_per_capita       0.501
# wind_energy_per_capita       NaN
# Name: 1400, Length: 123, dtype: object
# index                           8278
# iso_code                         KAZ
# country                   Kazakhstan
# year                            2006
# coal_prod_change_pct          11.196
#                              ...
# wind_share_energy                  0
# wind_cons_change_twh               0
# wind_consumption                   0
# wind_elec_per_capita           0.064
# wind_energy_per_capita             0
# Name: 1420, Length: 123, dtype: object
# index                      8319
# iso_code                    KEN
# country                   Kenya
# year                       2006
# coal_prod_change_pct        NaN
#                           ...
# wind_share_energy           NaN
# wind_cons_change_twh        NaN
# wind_consumption            NaN
# wind_elec_per_capita      0.027
# wind_energy_per_capita      NaN
# Name: 1440, Length: 123, dtype: object
# index                       8499
# iso_code                     KWT
# country                   Kuwait
# year                        2006
# coal_prod_change_pct         NaN
#                            ...
# wind_share_energy              0
# wind_cons_change_twh           0
# wind_consumption               0
# wind_elec_per_capita           0
# wind_energy_per_capita         0
# Name: 1460, Length: 123, dtype: object
# index                           8527
# iso_code                         KGZ
# country                   Kyrgyzstan
# year                            2006
# coal_prod_change_pct          -4.179
#                              ...
# wind_share_energy                NaN
# wind_cons_change_twh             NaN
# wind_consumption                 NaN
# wind_elec_per_capita               0
# wind_energy_per_capita           NaN
# Name: 1480, Length: 123, dtype: object
# index                       8602
# iso_code                     LVA
# country                   Latvia
# year                        2006
# coal_prod_change_pct         NaN
#                            ...
# wind_share_energy          0.279
# wind_cons_change_twh      -0.003
# wind_consumption           0.123
# wind_elec_per_capita      20.769
# wind_energy_per_capita    55.261
# Name: 1500, Length: 123, dtype: object
# index                        8643
# iso_code                      LBN
# country                   Lebanon
# year                         2006
# coal_prod_change_pct          NaN
#                            ...
# wind_share_energy             NaN
# wind_cons_change_twh          NaN
# wind_consumption              NaN
# wind_elec_per_capita            0
# wind_energy_per_capita        NaN
# Name: 1520, Length: 123, dtype: object
# index                      8843
# iso_code                    LBY
# country                   Libya
# year                       2006
# coal_prod_change_pct        NaN
#                           ...
# wind_share_energy           NaN
# wind_cons_change_twh        NaN
# wind_consumption            NaN
# wind_elec_per_capita          0
# wind_energy_per_capita      NaN
# Name: 1540, Length: 123, dtype: object
# index                          8883
# iso_code                        LTU
# country                   Lithuania
# year                           2006
# coal_prod_change_pct            NaN
#                             ...
# wind_share_energy             0.041
# wind_cons_change_twh          0.032
# wind_consumption              0.037
# wind_elec_per_capita          4.163
# wind_energy_per_capita       11.087
# Name: 1560, Length: 123, dtype: object
# index                           8939
# iso_code                         LUX
# country                   Luxembourg
# year                            2006
# coal_prod_change_pct             NaN
#                              ...
# wind_share_energy              0.301
# wind_cons_change_twh           0.014
# wind_consumption               0.155
# wind_elec_per_capita         124.433
# wind_energy_per_capita       332.605
# Name: 1580, Length: 123, dtype: object
# index                      8980
# iso_code                    MAC
# country                   Macau
# year                       2006
# coal_prod_change_pct        NaN
#                           ...
# wind_share_energy           NaN
# wind_cons_change_twh        NaN
# wind_consumption            NaN
# wind_elec_per_capita        NaN
# wind_energy_per_capita      NaN
# Name: 1600, Length: 123, dtype: object
# index                         9260
# iso_code                       MYS
# country                   Malaysia
# year                          2006
# coal_prod_change_pct           NaN
#                             ...
# wind_share_energy                0
# wind_cons_change_twh             0
# wind_consumption                 0
# wind_elec_per_capita             0
# wind_energy_per_capita           0
# Name: 1620, Length: 123, dtype: object
# index                      9380
# iso_code                    MLT
# country                   Malta
# year                       2006
# coal_prod_change_pct        NaN
#                           ...
# wind_share_energy           NaN
# wind_cons_change_twh        NaN
# wind_consumption            NaN
# wind_elec_per_capita          0
# wind_energy_per_capita      NaN
# Name: 1640, Length: 123, dtype: object
# index                          9501
# iso_code                        MUS
# country                   Mauritius
# year                           2006
# coal_prod_change_pct            NaN
#                             ...
# wind_share_energy               NaN
# wind_cons_change_twh            NaN
# wind_consumption                NaN
# wind_elec_per_capita          0.326
# wind_energy_per_capita          NaN
# Name: 1660, Length: 123, dtype: object
# index                       9621
# iso_code                     MEX
# country                   Mexico
# year                        2006
# coal_prod_change_pct      11.479
#                            ...
# wind_share_energy          0.006
# wind_cons_change_twh       0.069
# wind_consumption            0.12
# wind_elec_per_capita       0.549
# wind_energy_per_capita     1.118
# Name: 1680, Length: 123, dtype: object
# index                              9677
# iso_code                            NaN
# country                   Middle Africa
# year                               2006
# coal_prod_change_pct                NaN
#                               ...
# wind_share_energy                   NaN
# wind_cons_change_twh                NaN
# wind_consumption                    NaN
# wind_elec_per_capita                NaN
# wind_energy_per_capita              NaN
# Name: 1700, Length: 123, dtype: object
# index                            9797
# iso_code                          NaN
# country                   Middle East
# year                             2006
# coal_prod_change_pct            6.083
#                              ...
# wind_share_energy                 NaN
# wind_cons_change_twh              NaN
# wind_consumption                  NaN
# wind_elec_per_capita              NaN
# wind_energy_per_capita            NaN
# Name: 1720, Length: 123, dtype: object
# index                         9945
# iso_code                       MNG
# country                   Mongolia
# year                          2006
# coal_prod_change_pct          7.41
#                             ...
# wind_share_energy              NaN
# wind_cons_change_twh           NaN
# wind_consumption               NaN
# wind_elec_per_capita         0.005
# wind_energy_per_capita         NaN
# Name: 1740, Length: 123, dtype: object
# index                           9966
# iso_code                         MNE
# country                   Montenegro
# year                            2006
# coal_prod_change_pct             NaN
#                              ...
# wind_share_energy                NaN
# wind_cons_change_twh             NaN
# wind_consumption                 NaN
# wind_elec_per_capita               0
# wind_energy_per_capita           NaN
# Name: 1760, Length: 123, dtype: object
# index                       10126
# iso_code                      MAR
# country                   Morocco
# year                         2006
# coal_prod_change_pct            0
#                            ...
# wind_share_energy           0.298
# wind_cons_change_twh       -0.065
# wind_consumption             0.49
# wind_elec_per_capita        5.941
# wind_energy_per_capita     15.896
# Name: 1780, Length: 123, dtype: object
# index                          10246
# iso_code                         MOZ
# country                   Mozambique
# year                            2006
# coal_prod_change_pct          24.242
#                              ...
# wind_share_energy                NaN
# wind_cons_change_twh             NaN
# wind_consumption                 NaN
# wind_elec_per_capita               0
# wind_energy_per_capita           NaN
# Name: 1800, Length: 123, dtype: object
# index                       10366
# iso_code                      MMR
# country                   Myanmar
# year                         2006
# coal_prod_change_pct            0
#                            ...
# wind_share_energy             NaN
# wind_cons_change_twh          NaN
# wind_consumption              NaN
# wind_elec_per_capita          NaN
# wind_energy_per_capita        NaN
# Name: 1820, Length: 123, dtype: object
# index                       10396
# iso_code                      NAM
# country                   Namibia
# year                         2006
# coal_prod_change_pct          NaN
#                            ...
# wind_share_energy             NaN
# wind_cons_change_twh          NaN
# wind_consumption              NaN
# wind_elec_per_capita            0
# wind_energy_per_capita        NaN
# Name: 1840, Length: 123, dtype: object
# index                      10556
# iso_code                     NPL
# country                    Nepal
# year                        2006
# coal_prod_change_pct      29.204
#                            ...
# wind_share_energy            NaN
# wind_cons_change_twh         NaN
# wind_consumption             NaN
# wind_elec_per_capita           0
# wind_energy_per_capita       NaN
# Name: 1860, Length: 123, dtype: object
# index                           10676
# iso_code                          NLD
# country                   Netherlands
# year                             2006
# coal_prod_change_pct                0
#                              ...
# wind_share_energy               0.673
# wind_cons_change_twh            1.748
# wind_consumption                7.308
# wind_elec_per_capita          166.319
# wind_energy_per_capita        444.517
# Name: 1880, Length: 123, dtype: object
# index                                    10717
# iso_code                                   ANT
# country                   Netherlands Antilles
# year                                      2006
# coal_prod_change_pct                       NaN
#                                   ...
# wind_share_energy                          NaN
# wind_cons_change_twh                       NaN
# wind_consumption                           NaN
# wind_elec_per_capita                       NaN
# wind_energy_per_capita                     NaN
# Name: 1900, Length: 123, dtype: object
# index                           10812
# iso_code                          NZL
# country                   New Zealand
# year                             2006
# coal_prod_change_pct            7.605
#                              ...
# wind_share_energy               0.736
# wind_cons_change_twh            0.011
# wind_consumption                1.663
# wind_elec_per_capita          148.591
# wind_energy_per_capita        397.315
# Name: 1920, Length: 123, dtype: object
# index                         10853
# iso_code                        NIC
# country                   Nicaragua
# year                           2006
# coal_prod_change_pct            NaN
#                             ...
# wind_share_energy               NaN
# wind_cons_change_twh            NaN
# wind_consumption                NaN
# wind_elec_per_capita              0
# wind_energy_per_capita          NaN
# Name: 1940, Length: 123, dtype: object
# index                     10973
# iso_code                    NER
# country                   Niger
# year                       2006
# coal_prod_change_pct     -3.153
#                           ...
# wind_share_energy           NaN
# wind_cons_change_twh        NaN
# wind_consumption            NaN
# wind_elec_per_capita          0
# wind_energy_per_capita      NaN
# Name: 1960, Length: 123, dtype: object
# index                       11093
# iso_code                      NGA
# country                   Nigeria
# year                         2006
# coal_prod_change_pct            0
#                            ...
# wind_share_energy             NaN
# wind_cons_change_twh          NaN
# wind_consumption              NaN
# wind_elec_per_capita            0
# wind_energy_per_capita        NaN
# Name: 1980, Length: 123, dtype: object
# index                                        11444
# iso_code                                       MNP
# country                   Northern Mariana Islands
# year                                          2006
# coal_prod_change_pct                           NaN
#                                     ...
# wind_share_energy                              NaN
# wind_cons_change_twh                           NaN
# wind_consumption                               NaN
# wind_elec_per_capita                           NaN
# wind_energy_per_capita                         NaN
# Name: 2000, Length: 123, dtype: object
# index                       11564
# iso_code                      NOR
# country                    Norway
# year                         2009
# coal_prod_change_pct            0
#                            ...
# wind_share_energy           0.513
# wind_cons_change_twh        0.153
# wind_consumption            2.563
# wind_elec_per_capita      202.403
# wind_energy_per_capita    530.996
# Name: 2020, Length: 123, dtype: object
# index                      11685
# iso_code                     NaN
# country                     OPEC
# year                        2009
# coal_prod_change_pct     -24.771
#                            ...
# wind_share_energy            NaN
# wind_cons_change_twh         NaN
# wind_consumption             NaN
# wind_elec_per_capita         NaN
# wind_energy_per_capita       NaN
# Name: 2040, Length: 123, dtype: object
# index                     11805
# iso_code                    OMN
# country                    Oman
# year                       2012
# coal_prod_change_pct        NaN
#                           ...
# wind_share_energy             0
# wind_cons_change_twh          0
# wind_consumption              0
# wind_elec_per_capita          0
# wind_energy_per_capita        0
# Name: 2060, Length: 123, dtype: object
# index                                    11860
# iso_code                                   NaN
# country                   Other Asia & Pacific
# year                                      2012
# coal_prod_change_pct                     2.402
#                                   ...
# wind_share_energy                          NaN
# wind_cons_change_twh                       NaN
# wind_consumption                           NaN
# wind_elec_per_capita                       NaN
# wind_energy_per_capita                     NaN
# Name: 2080, Length: 123, dtype: object
# index                         11915
# iso_code                        NaN
# country                   Other CIS
# year                           2012
# coal_prod_change_pct          19.24
#                             ...
# wind_share_energy               NaN
# wind_cons_change_twh            NaN
# wind_consumption                NaN
# wind_elec_per_capita            NaN
# wind_energy_per_capita          NaN
# Name: 2100, Length: 123, dtype: object
# index                               11970
# iso_code                              NaN
# country                   Other Caribbean
# year                                 2012
# coal_prod_change_pct                  NaN
#                                ...
# wind_share_energy                     NaN
# wind_cons_change_twh                  NaN
# wind_consumption                      NaN
# wind_elec_per_capita                  NaN
# wind_energy_per_capita                NaN
# Name: 2120, Length: 123, dtype: object
# index                                 12025
# iso_code                                NaN
# country                   Other Middle East
# year                                   2012
# coal_prod_change_pct                    NaN
#                                 ...
# wind_share_energy                       NaN
# wind_cons_change_twh                    NaN
# wind_consumption                        NaN
# wind_elec_per_capita                    NaN
# wind_energy_per_capita                  NaN
# Name: 2140, Length: 123, dtype: object
# index                                     12080
# iso_code                                    NaN
# country                   Other Northern Africa
# year                                       2012
# coal_prod_change_pct                        NaN
#                                   ...
# wind_share_energy                           NaN
# wind_cons_change_twh                        NaN
# wind_consumption                            NaN
# wind_elec_per_capita                        NaN
# wind_energy_per_capita                      NaN
# Name: 2160, Length: 123, dtype: object
# index                                   12135
# iso_code                                  NaN
# country                   Other South America
# year                                     2012
# coal_prod_change_pct                      NaN
#                                  ...
# wind_share_energy                         NaN
# wind_cons_change_twh                      NaN
# wind_consumption                          NaN
# wind_elec_per_capita                      NaN
# wind_energy_per_capita                    NaN
# Name: 2180, Length: 123, dtype: object
# index                                     12190
# iso_code                                    NaN
# country                   Other Southern Africa
# year                                       2012
# coal_prod_change_pct                        NaN
#                                   ...
# wind_share_energy                           NaN
# wind_cons_change_twh                        NaN
# wind_consumption                            NaN
# wind_elec_per_capita                        NaN
# wind_energy_per_capita                      NaN
# Name: 2200, Length: 123, dtype: object
# index                        12310
# iso_code                       PAK
# country                   Pakistan
# year                          2012
# coal_prod_change_pct        -5.795
#                             ...
# wind_share_energy                0
# wind_cons_change_twh             0
# wind_consumption                 0
# wind_elec_per_capita             0
# wind_energy_per_capita           0
# Name: 2220, Length: 123, dtype: object
# index                      12374
# iso_code                     PAN
# country                   Panama
# year                        2012
# coal_prod_change_pct         NaN
#                            ...
# wind_share_energy            NaN
# wind_cons_change_twh         NaN
# wind_consumption             NaN
# wind_elec_per_capita           0
# wind_energy_per_capita       NaN
# Name: 2240, Length: 123, dtype: object
# index                        12454
# iso_code                       PRY
# country                   Paraguay
# year                          2012
# coal_prod_change_pct           NaN
#                             ...
# wind_share_energy              NaN
# wind_cons_change_twh           NaN
# wind_consumption               NaN
# wind_elec_per_capita             0
# wind_energy_per_capita         NaN
# Name: 2260, Length: 123, dtype: object
# index                     12574
# iso_code                    PER
# country                    Peru
# year                       2012
# coal_prod_change_pct          0
#                           ...
# wind_share_energy         0.001
# wind_cons_change_twh          0
# wind_consumption          0.003
# wind_elec_per_capita      0.034
# wind_energy_per_capita    0.105
# Name: 2280, Length: 123, dtype: object
# index                           12695
# iso_code                          PHL
# country                   Philippines
# year                             2012
# coal_prod_change_pct                0
#                              ...
# wind_share_energy               0.054
# wind_cons_change_twh           -0.035
# wind_consumption                0.194
# wind_elec_per_capita            0.772
# wind_energy_per_capita          1.996
# Name: 2300, Length: 123, dtype: object
# index                       12816
# iso_code                      POL
# country                    Poland
# year                         2012
# coal_prod_change_pct        3.769
#                            ...
# wind_share_energy            1.08
# wind_cons_change_twh        3.921
# wind_consumption           12.227
# wind_elec_per_capita      124.169
# wind_energy_per_capita    319.856
# Name: 2320, Length: 123, dtype: object
# index                        12937
# iso_code                       PRT
# country                   Portugal
# year                          2012
# coal_prod_change_pct             0
#                             ...
# wind_share_energy           10.116
# wind_cons_change_twh         2.684
# wind_consumption            26.427
# wind_elec_per_capita       974.708
# wind_energy_per_capita     2510.67
# Name: 2340, Length: 123, dtype: object
# index                     13098
# iso_code                    QAT
# country                   Qatar
# year                       2012
# coal_prod_change_pct        NaN
#                           ...
# wind_share_energy             0
# wind_cons_change_twh          0
# wind_consumption              0
# wind_elec_per_capita          0
# wind_energy_per_capita        0
# Name: 2360, Length: 123, dtype: object
# index                       13258
# iso_code                      ROU
# country                   Romania
# year                         2012
# coal_prod_change_pct       -4.743
#                            ...
# wind_share_energy           1.745
# wind_cons_change_twh        3.206
# wind_consumption              6.8
# wind_elec_per_capita      130.512
# wind_energy_per_capita    336.185
# Name: 2380, Length: 123, dtype: object
# index                            13755
# iso_code                           SAU
# country                   Saudi Arabia
# year                              2012
# coal_prod_change_pct               NaN
#                               ...
# wind_share_energy                    0
# wind_cons_change_twh                 0
# wind_consumption                     0
# wind_elec_per_capita                 0
# wind_energy_per_capita               0
# Name: 2400, Length: 123, dtype: object
# index                       13795
# iso_code                      SEN
# country                   Senegal
# year                         2012
# coal_prod_change_pct          NaN
#                            ...
# wind_share_energy             NaN
# wind_cons_change_twh          NaN
# wind_consumption              NaN
# wind_elec_per_capita            0
# wind_energy_per_capita        NaN
# Name: 2420, Length: 123, dtype: object
# index                      13823
# iso_code                     SRB
# country                   Serbia
# year                        2012
# coal_prod_change_pct      -6.319
#                            ...
# wind_share_energy            NaN
# wind_cons_change_twh         NaN
# wind_consumption             NaN
# wind_elec_per_capita           0
# wind_energy_per_capita       NaN
# Name: 2440, Length: 123, dtype: object
# index                         13959
# iso_code                        SGP
# country                   Singapore
# year                           2012
# coal_prod_change_pct            NaN
#                             ...
# wind_share_energy                 0
# wind_cons_change_twh              0
# wind_consumption                  0
# wind_elec_per_capita              0
# wind_energy_per_capita            0
# Name: 2460, Length: 123, dtype: object
# index                        14046
# iso_code                       SVN
# country                   Slovenia
# year                          2012
# coal_prod_change_pct           NaN
#                             ...
# wind_share_energy                0
# wind_cons_change_twh             0
# wind_consumption                 0
# wind_elec_per_capita             0
# wind_energy_per_capita           0
# Name: 2480, Length: 123, dtype: object
# index                                       14182
# iso_code                                      NaN
# country                   South & Central America
# year                                         2012
# coal_prod_change_pct                         3.06
#                                    ...
# wind_share_energy                             NaN
# wind_cons_change_twh                          NaN
# wind_consumption                              NaN
# wind_elec_per_capita                          NaN
# wind_energy_per_capita                        NaN
# Name: 2500, Length: 123, dtype: object
# index                            14302
# iso_code                           ZAF
# country                   South Africa
# year                              2012
# coal_prod_change_pct             2.355
#                               ...
# wind_share_energy                0.007
# wind_cons_change_twh            -0.001
# wind_consumption                 0.095
# wind_elec_per_capita             0.757
# wind_energy_per_capita           1.804
# Name: 2520, Length: 123, dtype: object
# index                           14445
# iso_code                          SSD
# country                   South Sudan
# year                             2012
# coal_prod_change_pct              NaN
#                              ...
# wind_share_energy                 NaN
# wind_cons_change_twh              NaN
# wind_consumption                  NaN
# wind_elec_per_capita                0
# wind_energy_per_capita            NaN
# Name: 2540, Length: 123, dtype: object
# index                       14565
# iso_code                      ESP
# country                     Spain
# year                         2012
# coal_prod_change_pct       -7.097
#                            ...
# wind_share_energy            7.69
# wind_cons_change_twh       17.464
# wind_consumption          127.428
# wind_elec_per_capita      1051.19
# wind_energy_per_capita     2707.6
# Name: 2560, Length: 123, dtype: object
# index                         14621
# iso_code                        LKA
# country                   Sri Lanka
# year                           2012
# coal_prod_change_pct            NaN
#                             ...
# wind_share_energy             0.544
# wind_cons_change_twh          0.141
# wind_consumption              0.378
# wind_elec_per_capita          7.159
# wind_energy_per_capita       18.416
# Name: 2580, Length: 123, dtype: object
# index                     14661
# iso_code                    SDN
# country                   Sudan
# year                       2012
# coal_prod_change_pct        NaN
#                           ...
# wind_share_energy           NaN
# wind_cons_change_twh        NaN
# wind_consumption            NaN
# wind_elec_per_capita          0
# wind_energy_per_capita      NaN
# Name: 2600, Length: 123, dtype: object
# index                        14781
# iso_code                       SUR
# country                   Suriname
# year                          2012
# coal_prod_change_pct           NaN
#                             ...
# wind_share_energy              NaN
# wind_cons_change_twh           NaN
# wind_consumption               NaN
# wind_elec_per_capita             0
# wind_energy_per_capita         NaN
# Name: 2620, Length: 123, dtype: object
# index                       14901
# iso_code                      SWE
# country                    Sweden
# year                         2012
# coal_prod_change_pct            0
#                            ...
# wind_share_energy           2.941
# wind_cons_change_twh        2.704
# wind_consumption           18.455
# wind_elec_per_capita      750.707
# wind_energy_per_capita    1933.91
# Name: 2640, Length: 123, dtype: object
# index                           14957
# iso_code                          CHE
# country                   Switzerland
# year                             2012
# coal_prod_change_pct              NaN
#                              ...
# wind_share_energy               0.066
# wind_cons_change_twh            0.045
# wind_consumption                0.227
# wind_elec_per_capita           10.989
# wind_energy_per_capita         28.305
# Name: 2660, Length: 123, dtype: object
# index                          15159
# iso_code                         TJK
# country                   Tajikistan
# year                            2012
# coal_prod_change_pct          74.576
#                              ...
# wind_share_energy                NaN
# wind_cons_change_twh             NaN
# wind_consumption                 NaN
# wind_elec_per_capita               0
# wind_energy_per_capita           NaN
# Name: 2680, Length: 123, dtype: object
# index                        15400
# iso_code                       THA
# country                   Thailand
# year                          2012
# coal_prod_change_pct       -20.681
#                             ...
# wind_share_energy            0.003
# wind_cons_change_twh         0.031
# wind_consumption             0.044
# wind_elec_per_capita         2.079
# wind_energy_per_capita       0.652
# Name: 2700, Length: 123, dtype: object
# index                     15455
# iso_code                    TGO
# country                    Togo
# year                       2012
# coal_prod_change_pct        NaN
#                           ...
# wind_share_energy           NaN
# wind_cons_change_twh        NaN
# wind_consumption            NaN
# wind_elec_per_capita          0
# wind_energy_per_capita      NaN
# Name: 2720, Length: 123, dtype: object
# index                                   15550
# iso_code                                  TTO
# country                   Trinidad and Tobago
# year                                     2012
# coal_prod_change_pct                      NaN
#                                  ...
# wind_share_energy                           0
# wind_cons_change_twh                        0
# wind_consumption                            0
# wind_elec_per_capita                        0
# wind_energy_per_capita                      0
# Name: 2740, Length: 123, dtype: object
# index                       15670
# iso_code                      TUN
# country                   Tunisia
# year                         2012
# coal_prod_change_pct          NaN
#                            ...
# wind_share_energy             NaN
# wind_cons_change_twh          NaN
# wind_consumption              NaN
# wind_elec_per_capita        18.07
# wind_energy_per_capita        NaN
# Name: 2760, Length: 123, dtype: object
# index                       15791
# iso_code                      TUR
# country                    Turkey
# year                         2012
# coal_prod_change_pct       -4.768
#                            ...
# wind_share_energy           1.064
# wind_cons_change_twh        2.854
# wind_consumption           15.096
# wind_elec_per_capita       78.191
# wind_energy_per_capita    202.219
# Name: 2780, Length: 123, dtype: object
# index                            15832
# iso_code                           TKM
# country                   Turkmenistan
# year                              2012
# coal_prod_change_pct               NaN
#                               ...
# wind_share_energy                    0
# wind_cons_change_twh                 0
# wind_consumption                     0
# wind_elec_per_capita                 0
# wind_energy_per_capita               0
# Name: 2800, Length: 123, dtype: object
# index                       16064
# iso_code                      UKR
# country                   Ukraine
# year                         2012
# coal_prod_change_pct        7.633
#                            ...
# wind_share_energy           0.052
# wind_cons_change_twh         0.51
# wind_consumption            0.742
# wind_elec_per_capita        6.336
# wind_energy_per_capita     16.332
# Name: 2820, Length: 123, dtype: object
# index                                    16120
# iso_code                                   ARE
# country                   United Arab Emirates
# year                                      2012
# coal_prod_change_pct                       NaN
#                                   ...
# wind_share_energy                            0
# wind_cons_change_twh                         0
# wind_consumption                             0
# wind_elec_per_capita                         0
# wind_energy_per_capita                       0
# Name: 2840, Length: 123, dtype: object
# index                              16240
# iso_code                             GBR
# country                   United Kingdom
# year                                2012
# coal_prod_change_pct              -8.231
#                                ...
# wind_share_energy                  2.152
# wind_cons_change_twh               9.754
# wind_consumption                  51.121
# wind_elec_per_capita             307.588
# wind_energy_per_capita           792.273
# Name: 2860, Length: 123, dtype: object
# index                             16361
# iso_code                            USA
# country                   United States
# year                               2012
# coal_prod_change_pct             -6.951
#                               ...
# wind_share_energy                 1.471
# wind_cons_change_twh             51.807
# wind_consumption                366.387
# wind_elec_per_capita            448.414
# wind_energy_per_capita          1166.67
# Name: 2880, Length: 123, dtype: object
# index                                             16402
# iso_code                                            NaN
# country                   United States Pacific Islands
# year                                               2012
# coal_prod_change_pct                                NaN
#                                       ...
# wind_share_energy                                   NaN
# wind_cons_change_twh                                NaN
# wind_consumption                                    NaN
# wind_elec_per_capita                                NaN
# wind_energy_per_capita                              NaN
# Name: 2900, Length: 123, dtype: object
# index                                            16442
# iso_code                                           VIR
# country                   United States Virgin Islands
# year                                              2015
# coal_prod_change_pct                               NaN
#                                       ...
# wind_share_energy                                  NaN
# wind_cons_change_twh                               NaN
# wind_consumption                                   NaN
# wind_elec_per_capita                                 0
# wind_energy_per_capita                             NaN
# Name: 2920, Length: 123, dtype: object
# index                       16482
# iso_code                      URY
# country                   Uruguay
# year                         2015
# coal_prod_change_pct          NaN
#                            ...
# wind_share_energy             NaN
# wind_cons_change_twh          NaN
# wind_consumption              NaN
# wind_elec_per_capita      605.217
# wind_energy_per_capita        NaN
# Name: 2940, Length: 123, dtype: object
# index                          16523
# iso_code                         UZB
# country                   Uzbekistan
# year                            2015
# coal_prod_change_pct           -10.1
#                              ...
# wind_share_energy                  0
# wind_cons_change_twh               0
# wind_consumption                   0
# wind_elec_per_capita               0
# wind_energy_per_capita             0
# Name: 2960, Length: 123, dtype: object
# index                         16683
# iso_code                        VEN
# country                   Venezuela
# year                           2015
# coal_prod_change_pct          0.132
#                             ...
# wind_share_energy                 0
# wind_cons_change_twh          0.003
# wind_consumption              0.003
# wind_elec_per_capita           2.36
# wind_energy_per_capita        0.106
# Name: 2980, Length: 123, dtype: object
# index                              16859
# iso_code                             NaN
# country                   Western Africa
# year                                2015
# coal_prod_change_pct                 NaN
#                                ...
# wind_share_energy                    NaN
# wind_cons_change_twh                 NaN
# wind_consumption                     NaN
# wind_elec_per_capita                 NaN
# wind_energy_per_capita               NaN
# Name: 3000, Length: 123, dtype: object
# index                              16899
# iso_code                             ESH
# country                   Western Sahara
# year                                2015
# coal_prod_change_pct                 NaN
#                                ...
# wind_share_energy                    NaN
# wind_cons_change_twh                 NaN
# wind_consumption                     NaN
# wind_elec_per_capita                   0
# wind_energy_per_capita               NaN
# Name: 3020, Length: 123, dtype: object
# index                        17019
# iso_code                  OWID_WRL
# country                      World
# year                          2015
# coal_prod_change_pct        -2.635
#                             ...
# wind_share_energy            1.394
# wind_cons_change_twh       305.767
# wind_consumption           2103.67
# wind_elec_per_capita       112.286
# wind_energy_per_capita     285.058
# Name: 3040, Length: 123, dtype: object
# index                     17070
# iso_code                    YEM
# country                   Yemen
# year                       2015
# coal_prod_change_pct        NaN
#                           ...
# wind_share_energy           NaN
# wind_cons_change_twh        NaN
# wind_consumption            NaN
# wind_elec_per_capita          0
# wind_energy_per_capita      NaN
# Name: 3060, Length: 123, dtype: object
# index                          17190
# iso_code                         NaN
# country                   Yugoslavia
# year                            2015
# coal_prod_change_pct               0
#                              ...
# wind_share_energy                NaN
# wind_cons_change_twh             NaN
# wind_consumption                 NaN
# wind_elec_per_capita             NaN
# wind_energy_per_capita           NaN
# Name: 3080, Length: 123, dtype: object
# index                      17310
# iso_code                     ZMB
# country                   Zambia
# year                        2018
# coal_prod_change_pct           0
#                            ...
# wind_share_energy            NaN
# wind_cons_change_twh         NaN
# wind_consumption             NaN
# wind_elec_per_capita           0
# wind_energy_per_capita       NaN
# Name: 3100, Length: 123, dtype: object
# index                        17430
# iso_code                       ZWE
# country                   Zimbabwe
# year                          2018
# coal_prod_change_pct        22.555
#                             ...
# wind_share_energy              NaN
# wind_cons_change_twh           NaN
# wind_consumption               NaN
# wind_elec_per_capita             0
# wind_energy_per_capita         NaN
# Name: 3120, Length: 123, dtype: object
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1201-8a00310dc466> in <module>
#      11             list_to_append.append(np.NaN)
#      12
# ---> 13 append_owid['rd'] = list_to_append
#
# ~/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3038         else:
#    3039             # set column
# -> 3040             self._set_item(key, value)
#    3041
#    3042     def _setitem_slice(self, key: slice, value):
#
# ~/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3114         """
#    3115         self._ensure_valid_index(value)
# -> 3116         value = self._sanitize_column(key, value)
#    3117         NDFrame._set_item(self, key, value)
#    3118
#
# ~/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3762
#    3763             # turn me into an ndarray
# -> 3764             value = sanitize_index(value, self.index)
#    3765             if not isinstance(value, (np.ndarray, Index)):
#    3766                 if isinstance(value, list) and len(value) > 0:
#
# ~/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/pandas/core/internals/construction.py in sanitize_index(data, index)
#     746     if len(data) != len(index):
#     747         raise ValueError(
# --> 748             "Length of values "
#     749             f"({len(data)}) "
#     750             "does not match length of index "
#
# ValueError: Length of values (3140) does not match length of index (3122)

# %%
append_ghg = owid_ghg
for index, row in append_ghg.iterrows():
    if row["country"] not in countries:
        append_ghg = append_ghg.drop(owid_ghg.index[index])
    elif row["year"] < 2000 or row["year"] > 2019:
        append_ghg = append_ghg.drop(owid_ghg.index[index])

append_ghg = append_ghg.reset_index()

# %%
append_ghg
# Out:
#       index iso_code   country  year       co2  consumption_co2  \
# 0       188      NaN    Africa  2000   886.562          620.049
# 1       189      NaN    Africa  2001   884.168          608.520
# 2       190      NaN    Africa  2002   892.575          600.140
# 3       191      NaN    Africa  2003   967.220          668.371
# 4       192      NaN    Africa  2004  1036.686          716.243
# ...     ...      ...       ...   ...       ...              ...
# 2535  25198      ZWE  Zimbabwe  2015    12.226           13.350
# 2536  25199      ZWE  Zimbabwe  2016    10.738           12.153
# 2537  25200      ZWE  Zimbabwe  2017     9.582           11.248
# 2538  25201      ZWE  Zimbabwe  2018    11.854           13.163
# 2539  25202      ZWE  Zimbabwe  2019    10.949           12.422
#
#       co2_growth_prct  co2_growth_abs  trade_co2  co2_per_capita  ...  \
# 0                6.76          56.165   -266.512           1.094  ...
# 1               -0.27          -2.394   -275.648           1.064  ...
# 2                0.95           8.406   -292.434           1.049  ...
# 3                8.36          74.645   -298.849           1.109  ...
# 4                7.18          69.466   -320.442           1.160  ...
# ...               ...             ...        ...             ...  ...
# 2535             2.69           0.320      1.124           0.885  ...
# 2536           -12.17          -1.488      1.415           0.765  ...
# 2537           -10.77          -1.156      1.666           0.673  ...
# 2538            23.72           2.273      1.308           0.821  ...
# 2539            -7.64          -0.905      1.473           0.748  ...
#
#       ghg_per_capita  methane  methane_per_capita  nitrous_oxide  \
# 0                NaN      NaN                 NaN            NaN
# 1                NaN      NaN                 NaN            NaN
# 2                NaN      NaN                 NaN            NaN
# 3                NaN      NaN                 NaN            NaN
# 4                NaN      NaN                 NaN            NaN
# ...              ...      ...                 ...            ...
# 2535           4.885    11.87               0.859           6.68
# 2536           4.703    11.92               0.850           6.55
# 2537             NaN      NaN                 NaN            NaN
# 2538             NaN      NaN                 NaN            NaN
# 2539             NaN      NaN                 NaN            NaN
#
#       nitrous_oxide_per_capita   population           gdp  \
# 0                          NaN  810984230.0           NaN
# 1                          NaN  830902539.0           NaN
# 2                          NaN  851298437.0           NaN
# 3                          NaN  872248336.0           NaN
# 4                          NaN  893842786.0           NaN
# ...                        ...          ...           ...
# 2535                     0.484   13814642.0  2.102746e+10
# 2536                     0.467   14030338.0  2.096179e+10
# 2537                       NaN   14236599.0  2.194784e+10
# 2538                       NaN   14438812.0  2.271535e+10
# 2539                       NaN   14645473.0           NaN
#
#       primary_energy_consumption  energy_per_capita  energy_per_gdp
# 0                       3192.725           3936.853             NaN
# 1                       3317.609           3992.775             NaN
# 2                       3354.459           3940.405             NaN
# 3                       3513.656           4028.276             NaN
# 4                       3765.085           4212.245             NaN
# ...                          ...                ...             ...
# 2535                      55.642           4027.628           2.223
# 2536                      47.500           3385.574           1.889
# 2537                         NaN                NaN             NaN
# 2538                         NaN                NaN             NaN
# 2539                         NaN                NaN             NaN
#
# [2540 rows x 59 columns]

# %%
append_co2 = append_ghg[['co2']]
append_owid = append_owid[append_owid['country'] != "Gibraltar"]
append_owid = append_owid.reset_index(drop=True)
test = append_owid
append_owid["co2"] = append_co2

# %%
append_owid
# Out:
#       Unnamed: 0  index iso_code   country  year  coal_prod_change_pct  \
# 0              0    220      NaN    Africa  2000                -0.087
# 1              1    221      NaN    Africa  2001                -0.248
# 2              2    222      NaN    Africa  2002                -1.673
# 3              3    223      NaN    Africa  2003                 7.458
# 4              4    224      NaN    Africa  2004                 2.181
# ...          ...    ...      ...       ...   ...                   ...
# 2535        2555  17427      ZWE  Zimbabwe  2015               -25.013
# 2536        2556  17428      ZWE  Zimbabwe  2016               -37.694
# 2537        2557  17429      ZWE  Zimbabwe  2017                 8.375
# 2538        2558  17430      ZWE  Zimbabwe  2018                22.555
# 2539        2559  17431      ZWE  Zimbabwe  2019               -35.015
#
#       coal_prod_change_twh  gas_prod_change_pct  gas_prod_change_twh  \
# 0                   -1.320               11.037              134.287
# 1                   -3.761                3.363               45.431
# 2                  -25.333                4.557               63.640
# 3                  111.037                7.425              108.417
# 4                   34.898                4.627               72.579
# ...                    ...                  ...                  ...
# 2535               -10.847                  NaN                  NaN
# 2536               -12.257                  NaN                  NaN
# 2537                 1.697                  NaN                  NaN
# 2538                 4.952                  NaN                  NaN
# 2539                -9.422                  NaN                  NaN
#
#       oil_prod_change_pct  ...           gdp  wind_share_elec  \
# 0                   7.284  ...           NaN            0.040
# 1                  -1.002  ...           NaN            0.091
# 2                   0.679  ...           NaN            0.092
# 3                   8.758  ...           NaN            0.107
# 4                  11.272  ...           NaN            0.144
# ...                   ...  ...           ...              ...
# 2535                  NaN  ...  2.503057e+10            0.000
# 2536                  NaN  ...  2.515176e+10            0.000
# 2537                  NaN  ...           NaN            0.000
# 2538                  NaN  ...           NaN            0.000
# 2539                  NaN  ...           NaN            0.000
#
#       wind_cons_change_pct  wind_share_energy  wind_cons_change_twh  \
# 0                  788.889              0.015                 0.434
# 1                  134.874              0.035                 0.659
# 2                    6.161              0.036                 0.071
# 3                   20.951              0.042                 0.255
# 4                   41.238              0.055                 0.608
# ...                    ...                ...                   ...
# 2535                   NaN                NaN                   NaN
# 2536                   NaN                NaN                   NaN
# 2537                   NaN                NaN                   NaN
# 2538                   NaN                NaN                   NaN
# 2539                   NaN                NaN                   NaN
#
#       wind_consumption  wind_elec_per_capita  wind_energy_per_capita  rd  \
# 0                0.489                 0.217                   0.603 NaN
# 1                1.148                 0.501                   1.382 NaN
# 2                1.219                 0.522                   1.432 NaN
# 3                1.474                 0.620                   1.690 NaN
# 4                2.082                 0.861                   2.330 NaN
# ...                ...                   ...                     ...  ..
# 2535               NaN                 0.000                     NaN NaN
# 2536               NaN                 0.000                     NaN NaN
# 2537               NaN                 0.000                     NaN NaN
# 2538               NaN                 0.000                     NaN NaN
# 2539               NaN                 0.000                     NaN NaN
#
#            co2
# 0      886.562
# 1      884.168
# 2      892.575
# 3      967.220
# 4     1036.686
# ...        ...
# 2535    12.226
# 2536    10.738
# 2537     9.582
# 2538    11.854
# 2539    10.949
#
# [2540 rows x 126 columns]

# %%
append_owid.to_csv("final_append.csv")

# %%
#cleaning for owid energy data
full_df = []
all_countries = owid['country'].unique()
for country in all_countries:
    if(country in countries):
        d = getOwidCountry(owid, country)
        d = d.set_index(d["year"])
        d.columns.name = None
        d = d.drop(["year", "iso_code"], axis=1)
        for i in d.columns:
            if i != "country":
                d = d.rename(columns={i : i+f"_{country}"})
        full_df.append(d)

for i in range(1, len(full_df)):
    country = full_df[i]["country"].values[0]
    full_df[i] = full_df[i].drop("country", axis=1)
    full_df[0] = full_df[0].join(full_df[i])

final_df = full_df[0].drop("country", axis=1)

full_df[0]
# Out:
#      country  coal_prod_change_pct_Africa  coal_prod_change_twh_Africa  \
# year
# 1900  Africa                          NaN                          NaN
# 1901  Africa                       67.810                        4.530
# 1902  Africa                       49.068                        5.500
# 1903  Africa                       35.697                        5.965
# 1904  Africa                       12.880                        2.921
# ...      ...                          ...                          ...
# 2015  Africa                       -3.991                      -73.097
# 2016  Africa                        1.235                       21.713
# 2017  Africa                        3.647                       64.936
# 2018  Africa                        2.823                       52.095
# 2019  Africa                       -2.561                      -48.591
#
#       gas_prod_change_pct_Africa  gas_prod_change_twh_Africa  \
# year
# 1900                         NaN                         NaN
# 1901                         NaN                       0.000
# 1902                         NaN                       0.000
# 1903                         NaN                       0.000
# 1904                         NaN                       0.000
# ...                          ...                         ...
# 2015                       2.653                      52.707
# 2016                       0.959                      19.564
# 2017                       8.873                     182.702
# 2018                       5.381                     120.640
# 2019                       0.715                      16.881
#
#       oil_prod_change_pct_Africa  oil_prod_change_twh_Africa  \
# year
# 1900                         NaN                         NaN
# 1901                         NaN                       0.000
# 1902                         NaN                       0.000
# 1903                         NaN                       0.000
# 1904                         NaN                       0.000
# ...                          ...                         ...
# 2015                      -1.012                     -45.882
# 2016                      -5.730                    -257.263
# 2017                       5.572                     235.821
# 2018                       2.528                     112.961
# 2019                       1.141                      52.284
#
#       energy_cons_change_pct_Africa  energy_cons_change_twh_Africa  \
# year
# 1900                            NaN                            NaN
# 1901                            NaN                            NaN
# 1902                            NaN                            NaN
# 1903                            NaN                            NaN
# 1904                            NaN                            NaN
# ...                             ...                            ...
# 2015                          1.432                         70.251
# 2016                          2.622                        130.431
# 2017                          2.256                        115.188
# 2018                          3.196                        166.863
# 2019                          2.461                        132.586
#
#       biofuel_share_elec_Africa  ...  solar_elec_per_capita_Zimbabwe  \
# year                             ...
# 1900                        NaN  ...                             NaN
# 1901                        NaN  ...                             NaN
# 1902                        NaN  ...                             NaN
# 1903                        NaN  ...                             NaN
# 1904                        NaN  ...                             NaN
# ...                         ...  ...                             ...
# 2015                        NaN  ...                           0.579
# 2016                        NaN  ...                           0.641
# 2017                        NaN  ...                           0.773
# 2018                        NaN  ...                           0.970
# 2019                        NaN  ...                           0.956
#
#       solar_energy_per_capita_Zimbabwe  gdp_Zimbabwe  \
# year
# 1900                               NaN           NaN
# 1901                               NaN           NaN
# 1902                               NaN           NaN
# 1903                               NaN           NaN
# 1904                               NaN           NaN
# ...                                ...           ...
# 2015                               NaN  2.503057e+10
# 2016                               NaN  2.515176e+10
# 2017                               NaN           NaN
# 2018                               NaN           NaN
# 2019                               NaN           NaN
#
#       wind_share_elec_Zimbabwe  wind_cons_change_pct_Zimbabwe  \
# year
# 1900                       NaN                            NaN
# 1901                       NaN                            NaN
# 1902                       NaN                            NaN
# 1903                       NaN                            NaN
# 1904                       NaN                            NaN
# ...                        ...                            ...
# 2015                       0.0                            NaN
# 2016                       0.0                            NaN
# 2017                       0.0                            NaN
# 2018                       0.0                            NaN
# 2019                       0.0                            NaN
#
#       wind_share_energy_Zimbabwe  wind_cons_change_twh_Zimbabwe  \
# year
# 1900                         NaN                            NaN
# 1901                         NaN                            NaN
# 1902                         NaN                            NaN
# 1903                         NaN                            NaN
# 1904                         NaN                            NaN
# ...                          ...                            ...
# 2015                         NaN                            NaN
# 2016                         NaN                            NaN
# 2017                         NaN                            NaN
# 2018                         NaN                            NaN
# 2019                         NaN                            NaN
#
#       wind_consumption_Zimbabwe  wind_elec_per_capita_Zimbabwe  \
# year
# 1900                        NaN                            NaN
# 1901                        NaN                            NaN
# 1902                        NaN                            NaN
# 1903                        NaN                            NaN
# 1904                        NaN                            NaN
# ...                         ...                            ...
# 2015                        NaN                            0.0
# 2016                        NaN                            0.0
# 2017                        NaN                            0.0
# 2018                        NaN                            0.0
# 2019                        NaN                            0.0
#
#       wind_energy_per_capita_Zimbabwe
# year
# 1900                              NaN
# 1901                              NaN
# 1902                              NaN
# 1903                              NaN
# 1904                              NaN
# ...                               ...
# 2015                              NaN
# 2016                              NaN
# 2017                              NaN
# 2018                              NaN
# 2019                              NaN
#
# [120 rows x 15352 columns]

# %%
#cleaning owid co2 data
full_df = []
all_countries = owid_ghg['country'].unique()
for country in all_countries:
    if(country in countries):
        d = getOwidCountry(owid_ghg, country)
        d = d.set_index(d["year"])
        d.columns.name = None
        d = d.drop(["year", "iso_code"], axis=1)
        for i in d.columns:
            if i != "country":
                d = d.rename(columns={i : i+f"_{country}"})
        full_df.append(d[[f"co2_{country}"]])

for i in range(1, len(full_df)):
    # country = full_df[i]["country"].values[0]
    # full_df[i] = full_df[i].drop("country", axis=1)
    full_df[0] = full_df[0].join(full_df[i])

final_df2 = full_df[0]

# %%
final_df = final_df.join(final_df2)

# %%
final_df.to_csv('final.csv', index=True)

# %%
final = pd.read_csv("final.csv")
final = final.set_index(final['year'])
final.index.name=None
final = final.drop('year', axis=1)

# %%
final = final.join(df)

# %%
final = final.iloc[100:, :]

# %%
rd['United States_rd']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c7e7b1ce6cd3> in <module>
# ----> 1 rd['United States_rd']
#
# NameError: name 'rd' is not defined
